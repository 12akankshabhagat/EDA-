# %% [markdown]
# # EDA - Lungs Cancer Project

# %% [markdown]
# ### 2. Do the EDA on the given dataset: Lung cancer, and extract some useful information from this.
#
# ### Dataset Description:
# Lung cancer is one of the most prevalent and deadly forms of cancer worldwide,  presenting significant
# challenges in early detection and effective treatment.  To aid in the global effort to understand and combat this
# disease,  we are excited to introduce our comprehensive Lung Cancer Dataset.
#
# dataset link :https://drive.google.com/file/d/1NilhULC0qdiorakl02u5U_kRTPa6KSUI/view?usp=drive_link

# %% [markdown]
# ## import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Dataset

# %%
df=pd.read_csv("dataset[1].csv")

# %%
df
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         M   65        1               1        1              2
# 1         F   55        1               2        2              1
# 2         F   78        2               2        1              1
# 3         M   60        2               1        1              1
# 4         F   80        1               1        2              1
# ...     ...  ...      ...             ...      ...            ...
# 2995      F   71        2               1        1              2
# 2996      F   75        1               2        1              1
# 2997      F   62        2               2        2              1
# 2998      M   30        1               1        2              2
# 2999      M   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# ...

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC_DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
#        'ALCOHOL_CONSUMING', 'COUGHING', 'SHORTNESS_OF_BREATH',
#        'SWALLOWING_DIFFICULTY', 'CHEST_PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   65        1               1        1              2
# 1      F   55        1               2        2              1
# 2      F   78        2               2        1              1
# 3      M   60        2               1        1              1
# 4      F   80        1               1        2              1
#
#    CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                2        1        2         2                  2         2
# 1                1        2        2         2                  1         1
# 2                1        2        1         2                  1         1
# 3                2        1        2         1                  1         2
# 4                1        2        1         2                  1         1
#
#    SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN LUNG_CANCER
# ...

# %%
df.tail()
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 2995      F   71        2               1        1              2
# 2996      F   75        1               2        1              1
# 2997      F   62        2               2        2              1
# 2998      M   30        1               1        2              2
# 2999      M   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 2995                2        1        1         1                  1
# 2996                1        2        2         2                  2
# 2997                2        2        2         2                  1
# 2998                2        2        2         2                  2
# 2999                1        1        2         2                  2
#
#       COUGHING  SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN  \
# 2995         2                    1                      1           2
# ...

# %%
df.dtypes
# Out:
# GENDER                   object
# AGE                       int64
# SMOKING                   int64
# YELLOW_FINGERS            int64
# ANXIETY                   int64
# PEER_PRESSURE             int64
# CHRONIC_DISEASE           int64
# FATIGUE                   int64
# ALLERGY                   int64
# WHEEZING                  int64
# ALCOHOL_CONSUMING         int64
# COUGHING                  int64
# SHORTNESS_OF_BREATH       int64
# SWALLOWING_DIFFICULTY     int64
# CHEST_PAIN                int64
# LUNG_CANCER              object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 3000 non-null   object
#  1   AGE                    3000 non-null   int64
#  2   SMOKING                3000 non-null   int64
#  3   YELLOW_FINGERS         3000 non-null   int64
#  4   ANXIETY                3000 non-null   int64
#  5   PEER_PRESSURE          3000 non-null   int64
#  6   CHRONIC_DISEASE        3000 non-null   int64
#  7   FATIGUE                3000 non-null   int64
#  8   ALLERGY                3000 non-null   int64
#  9   WHEEZING               3000 non-null   int64
#  10  ALCOHOL_CONSUMING      3000 non-null   int64
#  11  COUGHING               3000 non-null   int64
#  12  SHORTNESS_OF_BREATH    3000 non-null   int64
#  13  SWALLOWING_DIFFICULTY  3000 non-null   int64
#  14  CHEST_PAIN             3000 non-null   int64
# ...

# %%
df.describe()
# Out:
#                AGE      SMOKING  YELLOW_FINGERS      ANXIETY  PEER_PRESSURE  \
# count  3000.000000  3000.000000     3000.000000  3000.000000    3000.000000
# mean     55.169000     1.491000        1.514000     1.494000       1.499000
# std      14.723746     0.500002        0.499887     0.500047       0.500082
# min      30.000000     1.000000        1.000000     1.000000       1.000000
# 25%      42.000000     1.000000        1.000000     1.000000       1.000000
# 50%      55.000000     1.000000        2.000000     1.000000       1.000000
# 75%      68.000000     2.000000        2.000000     2.000000       2.000000
# max      80.000000     2.000000        2.000000     2.000000       2.000000
#
#        CHRONIC_DISEASE      FATIGUE      ALLERGY     WHEEZING  \
# count      3000.000000  3000.000000  3000.000000  3000.000000
# mean          1.509667     1.489667     1.506667     1.497333
# std           0.499990     0.499977     0.500039     0.500076
# ...

# %%
df.shape
# Out:
# (3000, 16)

# %%
df.size
# Out:
# 48000

# %%
df["LUNG_CANCER"].value_counts()
# Out:
# YES    1518
# NO     1482
# Name: LUNG_CANCER, dtype: int64

# %%
df.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC_DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL_CONSUMING        0
# COUGHING                 0
# SHORTNESS_OF_BREATH      0
# SWALLOWING_DIFFICULTY    0
# CHEST_PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
#Checking for Duplicates
df.duplicated().sum()
# Out:
# 2

# %%
#Removing Duplicates
df=df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2998 entries, 0 to 2999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 2998 non-null   object
#  1   AGE                    2998 non-null   int64
#  2   SMOKING                2998 non-null   int64
#  3   YELLOW_FINGERS         2998 non-null   int64
#  4   ANXIETY                2998 non-null   int64
#  5   PEER_PRESSURE          2998 non-null   int64
#  6   CHRONIC_DISEASE        2998 non-null   int64
#  7   FATIGUE                2998 non-null   int64
#  8   ALLERGY                2998 non-null   int64
#  9   WHEEZING               2998 non-null   int64
#  10  ALCOHOL_CONSUMING      2998 non-null   int64
#  11  COUGHING               2998 non-null   int64
#  12  SHORTNESS_OF_BREATH    2998 non-null   int64
#  13  SWALLOWING_DIFFICULTY  2998 non-null   int64
#  14  CHEST_PAIN             2998 non-null   int64
# ...

# %%
df.isnull()
# Out:
#       GENDER    AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      False  False    False           False    False          False
# 1      False  False    False           False    False          False
# 2      False  False    False           False    False          False
# 3      False  False    False           False    False          False
# 4      False  False    False           False    False          False
# ...      ...    ...      ...             ...      ...            ...
# 2995   False  False    False           False    False          False
# 2996   False  False    False           False    False          False
# 2997   False  False    False           False    False          False
# 2998   False  False    False           False    False          False
# 2999   False  False    False           False    False          False
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# ...

# %%
df["AGE"].mean()
# Out:
# 55.1714476317545

# %%
df
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         M   65        1               1        1              2
# 1         F   55        1               2        2              1
# 2         F   78        2               2        1              1
# 3         M   60        2               1        1              1
# 4         F   80        1               1        2              1
# ...     ...  ...      ...             ...      ...            ...
# 2995      F   71        2               1        1              2
# 2996      F   75        1               2        1              1
# 2997      F   62        2               2        2              1
# 2998      M   30        1               1        2              2
# 2999      M   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# ...

# %%
df[['GENDER' ,	'AGE' ,'LUNG_CANCER']]
# Out:
#      GENDER  AGE LUNG_CANCER
# 0         M   65          NO
# 1         F   55          NO
# 2         F   78         YES
# 3         M   60         YES
# 4         F   80          NO
# ...     ...  ...         ...
# 2995      F   71          NO
# 2996      F   75          NO
# 2997      F   62         YES
# 2998      M   30         YES
# 2999      M   40         YES
#
# [2998 rows x 3 columns]

# %%
df['LUNG_CANCER' 'SMOKING'] = "yes"
df
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         M   65        1               1        1              2
# 1         F   55        1               2        2              1
# 2         F   78        2               2        1              1
# 3         M   60        2               1        1              1
# 4         F   80        1               1        2              1
# ...     ...  ...      ...             ...      ...            ...
# 2995      F   71        2               1        1              2
# 2996      F   75        1               2        1              1
# 2997      F   62        2               2        2              1
# 2998      M   30        1               1        2              2
# 2999      M   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# ...

# %%
df["AGE"].mean()
# Out:
# 55.1714476317545

# %%
gender_counts = df['GENDER'].value_counts()
print(gender_counts)
# Out:
# M    1512
# F    1486
# Name: GENDER, dtype: int64

# %%
df_gender=df[["GENDER","LUNG_CANCER"]]
plt.figure(figsize=(6,3))
sns.countplot(x="GENDER" ,hue="LUNG_CANCER",data=df_gender)
plt.title("Lung cancer according to Gender")
# Out:
# Text(0.5, 1.0, 'Lung cancer according to Gender')

# %% [markdown]
# Observation :
#
# male & female are equally effected having little difference.

# %%
sns.countplot(x="GENDER", hue="LUNG_CANCER", data=df_gender, palette=["green", "yellow"])
# Out:
# <AxesSubplot: xlabel='GENDER', ylabel='count'>

# %%
pie_df=df["LUNG_CANCER"].value_counts()
pie_df.plot(kind="pie",figsize=(5,5),autopct="%1.1f%%")
plt.show()

# %% [markdown]
# Observation and Insight
#
# 50.6% people has lung cancer.
#
# 49.4% people not having lung cancer.

# %%
# Check if 'SMOKING' column exists
if 'SMOKING' in df.columns:
    plt.figure(figsize=(10, 5))
    sns.countplot(x='SMOKING', hue='LUNG_CANCER', data=df, palette=['yellow' ,'green'])
    plt.title('Lung Cancer Distribution by Smoking Status')
    plt.xlabel('Smoking Status')
    plt.ylabel('Count')
    plt.show()

# %%
df_smoking_causes_lung_cancer = df.groupby("SMOKING")["LUNG_CANCER"].value_counts().unstack()
df_smoking_causes_lung_cancer
# Out:
# LUNG_CANCER   NO  YES
# SMOKING
# 1            764  761
# 2            717  756

# %%
fig,ax =plt.subplots(1,2,figsize= (11,5))
ax[0].pie(df_smoking_causes_lung_cancer.iloc[0],labels=["Positive","Negative"],autopct="%1.1f%%",startangle=90)
ax[0].set_title('Lung Cancer Distribution Among non-Smokers')

ax[1].pie(df_smoking_causes_lung_cancer.iloc[1],labels=["Positive","Negative"],autopct="%1.1f%%",startangle=90)
ax[1].set_title('Lung Cancer Distribution Among Smokers')

plt.show()

# %% [markdown]
# Observation :
#
# Smoking  is main Causes of Lung Cancer.

# %%
# Create age bins
age_bins = [0, 20, 40, 60, 80, 100]
age_labels = ['0-20', '21-40', '41-60', '61-80', '80+']
df['AGE_GROUP'] = pd.cut(df['AGE'], bins=age_bins, labels=age_labels)

# Plot Lung Cancer distribution by Age Group
plt.figure(figsize=(10, 5))
sns.countplot(x='AGE_GROUP', hue='LUNG_CANCER', data=df, palette=['Blue', 'Pink'])
plt.title('Lung Cancer Distribution by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.show()

# %%
# YELLOW_FINGERS count
plt.figure(figsize=(12,5))
ax =sns.countplot(x="YELLOW_FINGERS", data=df,hue="LUNG_CANCER")

for i in ax.containers:
    ax.bar_label(i)

plt.legend(["Does not have cancer","Has cancer"])
plt.show()

# %%
plt.figure(figsize=(12,5))
ax =sns.countplot(x="CHEST_PAIN", data=df,hue="LUNG_CANCER")

for i in ax.containers:
    ax.bar_label(i)

plt.legend(["Does not have cancer","Has cancer"])
plt.show()

# %%
# Histogram of numerical features
df.hist(figsize=(12, 8))
plt.show()

# Correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# ### Observation and Insight :
#
# 1. Smokers are slightly more in the Dataset.
#
# 2. 50.6% people has lung cancer.
#
# 3. 49.4% people not having lung cancer.
#
# 4. male & female are equally effected having little difference.
#
# 5. people of age 40 to 80 are effected by lungs cancer .
#
#
# 6.lungs cancer patient have more chest pain.
#
# 7.symptoms such as yellow fingers, Wheezing , coughing, fatigue, shortness of breath and chest pain meaning
#  these are symptoms of lungs cancer .
