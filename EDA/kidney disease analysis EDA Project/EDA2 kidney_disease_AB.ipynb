# %% [markdown]
# ### import neccesary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

plt.style.use("fivethirtyeight")
# %matplotlib inline

pd.set_option('display.max_columns', 30)

# %%
df = pd.read_csv("kidney_disease.csv")

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#      bgr    bu   sc    sod  pot  hemo pcv    wc   rc  htn   dm cad appet   pe  \
# 0  121.0  36.0  1.2    NaN  NaN  15.4  44  7800  5.2  yes  yes  no  good   no
# 1    NaN  18.0  0.8    NaN  NaN  11.3  38  6000  NaN   no   no  no  good   no
# 2  423.0  53.0  1.8    NaN  NaN   9.6  31  7500  NaN   no  yes  no  poor   no
# 3  117.0  56.0  3.8  111.0  2.5  11.2  32  6700  3.9  yes   no  no  poor  yes
# 4  106.0  26.0  1.4    NaN  NaN  11.6  35  7300  4.6   no   no  no  good   no
#
#    ane classification
# ...

# %%
df.tail()
# Out:
#       id   age    bp     sg   al   su     rbc      pc         pcc          ba  \
# 395  395  55.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
#
#        bgr    bu   sc    sod  pot  hemo pcv    wc   rc htn  dm cad appet  pe  \
# 395  140.0  49.0  0.5  150.0  4.9  15.7  47  6700  4.9  no  no  no  good  no
# 396   75.0  31.0  1.2  141.0  3.5  16.5  54  7800  6.2  no  no  no  good  no
# 397  100.0  26.0  0.6  137.0  4.4  15.8  49  6600  5.4  no  no  no  good  no
# 398  114.0  50.0  1.0  135.0  4.9  14.2  51  7200  5.9  no  no  no  good  no
# 399  131.0  18.0  1.1  141.0  3.5  15.8  53  6800  6.1  no  no  no  good  no
#
#     ane classification
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
df.shape
# Out:
# (400, 26)

# %%
df.dtypes
# Out:
# id                  int64
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv                object
# wc                 object
# rc                 object
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification     object
# dtype: object

# %%
df.id
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 395    395
# 396    396
# 397    397
# 398    398
# 399    399
# Name: id, Length: 400, dtype: int64

# %%
## drop id column bcoz not make sence

# %%
df.drop('id' , axis = 1 , inplace=True)

# %%
df  ## id col is droped
# Out:
#       age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0    48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1     7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2    62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3    48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4    51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
# ..    ...   ...    ...  ...  ...     ...       ...         ...         ...
# 395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
#
# ...

# %%
df.columns = [ 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
       'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
       'appet', 'pe', 'ane', 'classification']

# %%
df.columns = ['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell',
              'pus_cell_clumps', 'bacteria', 'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
              'potassium', 'haemoglobin', 'packed_cell_volume', 'white_blood_cell_count', 'red_blood_cell_count',
              'hypertension', 'diabetes_mellitus', 'coronary_artery_disease', 'appetite', 'peda_edema',
              'aanemia', 'class']

# %%
df
# Out:
#       age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0    48.0            80.0             1.020      1.0    0.0             NaN
# 1     7.0            50.0             1.020      4.0    0.0             NaN
# 2    62.0            80.0             1.010      2.0    3.0          normal
# 3    48.0            70.0             1.005      4.0    0.0          normal
# 4    51.0            80.0             1.010      2.0    0.0          normal
# ..    ...             ...               ...      ...    ...             ...
# 395  55.0            80.0             1.020      0.0    0.0          normal
# 396  42.0            70.0             1.025      0.0    0.0          normal
# 397  12.0            80.0             1.020      0.0    0.0          normal
# 398  17.0            60.0             1.025      0.0    0.0          normal
# 399  58.0            80.0             1.025      0.0    0.0          normal
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      391 non-null    float64
#  1   blood_pressure           388 non-null    float64
#  2   specific_gravity         353 non-null    float64
#  3   albumin                  354 non-null    float64
#  4   sugar                    351 non-null    float64
#  5   red_blood_cells          248 non-null    object
#  6   pus_cell                 335 non-null    object
#  7   pus_cell_clumps          396 non-null    object
#  8   bacteria                 396 non-null    object
#  9   blood_glucose_random     356 non-null    float64
#  10  blood_urea               381 non-null    float64
#  11  serum_creatinine         383 non-null    float64
#  12  sodium                   313 non-null    float64
#  13  potassium                312 non-null    float64
# ...

# %%
df['age'] = pd.to_numeric(df.age, errors = 'coerce')

# %%
df['age']
# Out:
# 0      48.0
# 1       7.0
# 2      62.0
# 3      48.0
# 4      51.0
#        ...
# 395    55.0
# 396    42.0
# 397    12.0
# 398    17.0
# 399    58.0
# Name: age, Length: 400, dtype: float64

# %%
# age is in float format , dtype is also float , so its ok.

# %%
df['packed_cell_volume']
# Out:
# 0      44
# 1      38
# 2      31
# 3      32
# 4      35
#        ..
# 395    47
# 396    54
# 397    49
# 398    51
# 399    53
# Name: packed_cell_volume, Length: 400, dtype: object

# %%
df['packed_cell_volume'] = pd.to_numeric(df.packed_cell_volume, errors = 'coerce')

# %%
df['packed_cell_volume']
# Out:
# 0      44.0
# 1      38.0
# 2      31.0
# 3      32.0
# 4      35.0
#        ...
# 395    47.0
# 396    54.0
# 397    49.0
# 398    51.0
# 399    53.0
# Name: packed_cell_volume, Length: 400, dtype: float64

# %%
df['white_blood_cell_count']
# Out:
# 0      7800
# 1      6000
# 2      7500
# 3      6700
# 4      7300
#        ...
# 395    6700
# 396    7800
# 397    6600
# 398    7200
# 399    6800
# Name: white_blood_cell_count, Length: 400, dtype: object

# %%
#pd.to_numeric
#errors = 'coerce'    # coerce means supress the eroor.

# %%
df['white_blood_cell_count'] = pd.to_numeric(df.white_blood_cell_count, errors = 'coerce')

# %%
df['white_blood_cell_count']
# Out:
# 0      7800.0
# 1      6000.0
# 2      7500.0
# 3      6700.0
# 4      7300.0
#         ...
# 395    6700.0
# 396    7800.0
# 397    6600.0
# 398    7200.0
# 399    6800.0
# Name: white_blood_cell_count, Length: 400, dtype: float64

# %%
df
# Out:
#       age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0    48.0            80.0             1.020      1.0    0.0             NaN
# 1     7.0            50.0             1.020      4.0    0.0             NaN
# 2    62.0            80.0             1.010      2.0    3.0          normal
# 3    48.0            70.0             1.005      4.0    0.0          normal
# 4    51.0            80.0             1.010      2.0    0.0          normal
# ..    ...             ...               ...      ...    ...             ...
# 395  55.0            80.0             1.020      0.0    0.0          normal
# 396  42.0            70.0             1.025      0.0    0.0          normal
# 397  12.0            80.0             1.020      0.0    0.0          normal
# 398  17.0            60.0             1.025      0.0    0.0          normal
# 399  58.0            80.0             1.025      0.0    0.0          normal
#
# ...

# %%
## categorical column : aplabeths value

cat_cols = [col for col in df.columns if df[col].dtype =='object']

# %%
cat_cols
# Out:
# ['red_blood_cells',
#  'pus_cell',
#  'pus_cell_clumps',
#  'bacteria',
#  'red_blood_cell_count',
#  'hypertension',
#  'diabetes_mellitus',
#  'coronary_artery_disease',
#  'appetite',
#  'peda_edema',
#  'aanemia',
#  'class']

# %%
## we can write O in place of object
cat_cols = [col for col in df.columns if df[col].dtype =='O']

# %%
cat_cols
# Out:
# ['red_blood_cells',
#  'pus_cell',
#  'pus_cell_clumps',
#  'bacteria',
#  'red_blood_cell_count',
#  'hypertension',
#  'diabetes_mellitus',
#  'coronary_artery_disease',
#  'appetite',
#  'peda_edema',
#  'aanemia',
#  'class']

# %%
## numeric value : number in dataframe.
num_cols = [col for col in df.columns if df[col].dtype !='O']

# %%
num_cols
# Out:
# ['age',
#  'blood_pressure',
#  'specific_gravity',
#  'albumin',
#  'sugar',
#  'blood_glucose_random',
#  'blood_urea',
#  'serum_creatinine',
#  'sodium',
#  'potassium',
#  'haemoglobin',
#  'packed_cell_volume',
#  'white_blood_cell_count']

# %%
cat_cols
# Out:
# ['red_blood_cells',
#  'pus_cell',
#  'pus_cell_clumps',
#  'bacteria',
#  'red_blood_cell_count',
#  'hypertension',
#  'diabetes_mellitus',
#  'coronary_artery_disease',
#  'appetite',
#  'peda_edema',
#  'aanemia',
#  'class']

# %%
num_cols
# Out:
# ['age',
#  'blood_pressure',
#  'specific_gravity',
#  'albumin',
#  'sugar',
#  'blood_glucose_random',
#  'blood_urea',
#  'serum_creatinine',
#  'sodium',
#  'potassium',
#  'haemoglobin',
#  'packed_cell_volume',
#  'white_blood_cell_count']

# %%
### to get unique value in dataset

for col in cat_cols:
  print(f"{col} has {df[col].unique()} values. \n")
# Out:
# red_blood_cells has [nan 'normal' 'abnormal'] values.
#
# pus_cell has ['normal' 'abnormal' nan] values.
#
# pus_cell_clumps has ['notpresent' 'present' nan] values.
#
# bacteria has ['notpresent' 'present' nan] values.
#
# red_blood_cell_count has ['5.2' nan '3.9' '4.6' '4.4' '5' '4.0' '3.7' '3.8' '3.4' '2.6' '2.8' '4.3'
#  '3.2' '3.6' '4' '4.1' '4.9' '2.5' '4.2' '4.5' '3.1' '4.7' '3.5' '6.0'
#  '5.0' '2.1' '5.6' '2.3' '2.9' '2.7' '8.0' '3.3' '3.0' '3' '2.4' '4.8'
#  '\t?' '5.4' '6.1' '6.2' '6.3' '5.1' '5.8' '5.5' '5.3' '6.4' '5.7' '5.9'
#  '6.5'] values.
#
# hypertension has ['yes' 'no' nan] values.
#
# diabetes_mellitus has ['yes' 'no' ' yes' '\tno' '\tyes' nan] values.
#
# coronary_artery_disease has ['no' 'yes' '\tno' nan] values.
#
# appetite has ['good' 'poor' nan] values.
#
# peda_edema has ['no' 'yes' nan] values.
#
# aanemia has ['no' 'yes' nan] values.
#
# class has ['ckd' 'ckd\t' 'notckd'] values.

# %%
df['diabetes_mellitus'].replace(to_replace = {'\tno' : 'no' , '\tyes': 'yes' , 'yes':'yes'},inplace = True)

# %%
for col in cat_cols:
  print(f"{col} has {df[col].unique()} values. \n")

  ## in diabetes col no \ value, i replce it.
# Out:
# red_blood_cells has [nan 'normal' 'abnormal'] values.
#
# pus_cell has ['normal' 'abnormal' nan] values.
#
# pus_cell_clumps has ['notpresent' 'present' nan] values.
#
# bacteria has ['notpresent' 'present' nan] values.
#
# red_blood_cell_count has ['5.2' nan '3.9' '4.6' '4.4' '5' '4.0' '3.7' '3.8' '3.4' '2.6' '2.8' '4.3'
#  '3.2' '3.6' '4' '4.1' '4.9' '2.5' '4.2' '4.5' '3.1' '4.7' '3.5' '6.0'
#  '5.0' '2.1' '5.6' '2.3' '2.9' '2.7' '8.0' '3.3' '3.0' '3' '2.4' '4.8'
#  '\t?' '5.4' '6.1' '6.2' '6.3' '5.1' '5.8' '5.5' '5.3' '6.4' '5.7' '5.9'
#  '6.5'] values.
#
# hypertension has ['yes' 'no' nan] values.
#
# diabetes_mellitus has ['yes' 'no' ' yes' nan] values.
#
# coronary_artery_disease has ['no' 'yes' '\tno' nan] values.
#
# appetite has ['good' 'poor' nan] values.
#
# peda_edema has ['no' 'yes' nan] values.
#
# aanemia has ['no' 'yes' nan] values.
#
# class has ['ckd' 'ckd\t' 'notckd'] values.

# %%
df['coronary_artery_disease'].replace(to_replace ='\tno', inplace = True)

# %%
df['coronary_artery_disease']
# Out:
# 0      no
# 1      no
# 2      no
# 3      no
# 4      no
#        ..
# 395    no
# 396    no
# 397    no
# 398    no
# 399    no
# Name: coronary_artery_disease, Length: 400, dtype: object

# %%
## other approch

df['coronary_artery_disease'] = df['coronary_artery_disease'].replace(to_replace ='\tno', value = 'no')

# %%
df['coronary_artery_disease']
# Out:
# 0      no
# 1      no
# 2      no
# 3      no
# 4      no
#        ..
# 395    no
# 396    no
# 397    no
# 398    no
# 399    no
# Name: coronary_artery_disease, Length: 400, dtype: object

# %%
df['class']
# Out:
# 0         ckd
# 1         ckd
# 2         ckd
# 3         ckd
# 4         ckd
#         ...
# 395    notckd
# 396    notckd
# 397    notckd
# 398    notckd
# 399    notckd
# Name: class, Length: 400, dtype: object

# %%
df['class'].replace(to_replace = {'ckd\t' : 'ckd' , 'notckd' : 'not ckd'}, inplace = True)

# %%
for col in cat_cols:
  print(f"{col} has {df[col].unique()} values. \n")
# Out:
# red_blood_cells has [nan 'normal' 'abnormal'] values.
#
# pus_cell has ['normal' 'abnormal' nan] values.
#
# pus_cell_clumps has ['notpresent' 'present' nan] values.
#
# bacteria has ['notpresent' 'present' nan] values.
#
# red_blood_cell_count has ['5.2' nan '3.9' '4.6' '4.4' '5' '4.0' '3.7' '3.8' '3.4' '2.6' '2.8' '4.3'
#  '3.2' '3.6' '4' '4.1' '4.9' '2.5' '4.2' '4.5' '3.1' '4.7' '3.5' '6.0'
#  '5.0' '2.1' '5.6' '2.3' '2.9' '2.7' '8.0' '3.3' '3.0' '3' '2.4' '4.8'
#  '\t?' '5.4' '6.1' '6.2' '6.3' '5.1' '5.8' '5.5' '5.3' '6.4' '5.7' '5.9'
#  '6.5'] values.
#
# hypertension has ['yes' 'no' nan] values.
#
# diabetes_mellitus has ['yes' 'no' ' yes' nan] values.
#
# coronary_artery_disease has ['no' 'yes' nan] values.
#
# appetite has ['good' 'poor' nan] values.
#
# peda_edema has ['no' 'yes' nan] values.
#
# aanemia has ['no' 'yes' nan] values.
#
# class has ['ckd' 'not ckd'] values.

# %%
# ckd = cronic disease
# not ckd = not cronic disease

# %%
df['class'].unique()
# Out:
# array(['ckd', 'not ckd'], dtype=object)

# %%
df['class'].unique()
# Out:
# array(['ckd', 'not ckd'], dtype=object)

# %%
# ckd not make sence , replace with int

# %%
df['class'] = df['class'].map({'ckd':0 , 'not ckd' : 1})

# %%
df['class']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    1
# 399    1
# Name: class, Length: 400, dtype: int64

# %%
intdf = df['class'].value_counts()

# %%
intdf
# Out:
# class
# 0    250
# 1    150
# Name: count, dtype: int64

# %%
## eda : to do EDA remove null value  must to analyse given data corectly.

# %%
## univariate analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      391 non-null    float64
#  1   blood_pressure           388 non-null    float64
#  2   specific_gravity         353 non-null    float64
#  3   albumin                  354 non-null    float64
#  4   sugar                    351 non-null    float64
#  5   red_blood_cells          248 non-null    object
#  6   pus_cell                 335 non-null    object
#  7   pus_cell_clumps          396 non-null    object
#  8   bacteria                 396 non-null    object
#  9   blood_glucose_random     356 non-null    float64
#  10  blood_urea               381 non-null    float64
#  11  serum_creatinine         383 non-null    float64
#  12  sodium                   313 non-null    float64
#  13  potassium                312 non-null    float64
# ...

# %%
df.isnull().sum()     #or # df.isna().sum()
# Out:
# age                          9
# blood_pressure              12
# specific_gravity            47
# albumin                     46
# sugar                       49
# red_blood_cells            152
# pus_cell                    65
# pus_cell_clumps              4
# bacteria                     4
# blood_glucose_random        44
# blood_urea                  19
# serum_creatinine            17
# sodium                      87
# potassium                   88
# haemoglobin                 52
# packed_cell_volume          71
# white_blood_cell_count     106
# red_blood_cell_count       130
# hypertension                 2
# diabetes_mellitus            2
# coronary_artery_disease      2
# appetite                     1
# peda_edema                   1
# aanemia                      1
# class                        0
# dtype: int64

# %%
# age col has 9 null value ,bp col has 12 null value & so on.

# %%
df
# Out:
#       age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0    48.0            80.0             1.020      1.0    0.0             NaN
# 1     7.0            50.0             1.020      4.0    0.0             NaN
# 2    62.0            80.0             1.010      2.0    3.0          normal
# 3    48.0            70.0             1.005      4.0    0.0          normal
# 4    51.0            80.0             1.010      2.0    0.0          normal
# ..    ...             ...               ...      ...    ...             ...
# 395  55.0            80.0             1.020      0.0    0.0          normal
# 396  42.0            70.0             1.025      0.0    0.0          normal
# 397  12.0            80.0             1.020      0.0    0.0          normal
# 398  17.0            60.0             1.025      0.0    0.0          normal
# 399  58.0            80.0             1.025      0.0    0.0          normal
#
# ...

# %%
df['age']
# Out:
# 0      48.0
# 1       7.0
# 2      62.0
# 3      48.0
# 4      51.0
#        ...
# 395    55.0
# 396    42.0
# 397    12.0
# 398    17.0
# 399    58.0
# Name: age, Length: 400, dtype: float64

# %%
## univariate analysis

# %%
plt.figure(figsize = (10,6))
sns.distplot(df['age'])
plt.show()

# %%
plt.figure(figsize = (10 , 6))
sns.histplot(df['age'].dropna() , kde = True, color = 'blue') #droped null value
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('frequency')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#insight :(this is plot of age distribution)
#  most of people are around 40-65
# 70-80 age grp low no. of people

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
# Q. how many people having cronic disease has hypertension?

# %%
df.hypertension # is categorical col , so i make count plot
# Out:
# 0      yes
# 1       no
# 2       no
# 3      yes
# 4       no
#       ...
# 395     no
# 396     no
# 397     no
# 398     no
# 399     no
# Name: hypertension, Length: 400, dtype: object

# %%
# colunt plot , is used to count how many people have cronic disease

# %%
df_temp = df[df['class'] == 0]

# %%
df_temp['hypertension'].value_counts()
# Out:
# hypertension
# yes    147
# no     103
# Name: count, dtype: int64

# %%
# Q. how many people having  hypertension?

plt.figure(figsize = (10 , 6))
sns.countplot(x = 'hypertension', data = df, palette = 'viridis')
plt.title('count of hypertension')
plt.xlabel('hypertension')
plt.ylabel('count')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# insight :
# 1. the 150 people having  hypertension.
# 2. 250 people have not hypertension

# %%
# Q. how many people having blood_pressure?

plt.figure(figsize = (10 , 6))
sns.countplot(x = 'blood_pressure', data = df, palette = 'viridis')
plt.title('count of blood_pressure')
plt.xlabel('blood_pressure')
plt.ylabel('count')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# around 100-120 people have blood pressure

# %%
# Q. how many people having sugar? #histplot

plt.figure(figsize = (10 , 6))
sns.histplot(x = 'sugar', data = df, palette = 'viridis')
plt.title('count of sugar')
plt.xlabel('sugar')
plt.ylabel('count')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# around 300 people having suger

# %%
# Q. how many people having coronary_artery_disease? #histplot

plt.figure(figsize = (10 , 6))
sns.countplot(x = 'coronary_artery_disease', data = df, palette = 'viridis')
plt.title('count of coronary_artery_disease')
plt.xlabel('coronary_artery_disease')
plt.ylabel('count')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# less no. of people having coronary_artery_disease.

# %%
## Box plot : its used to know outliers.

# %%
# box plot

plt.figure(figsize = (10 , 6))
sns.boxplot(x ='class', y = 'blood_urea',data = df)
plt.xlabel('class')
plt.ylabel('blood urea')
plt.title('boxplot of blood urea by class')
plt.show()

# %%
## insight :
# zero class of blood urea, having points above line , is outliers.
# no outlier in column 1.

# %%
## vilin plot: its gives outlier.

plt.figure(figsize = (10 , 6))
sns.violinplot(x ='class', y = 'blood_urea',data = df)
plt.xlabel('class')
plt.ylabel('blood urea')
plt.title('violinplot of blood urea by class')
plt.show()

# %%
sns.countplot(x = 'aanemia' , data=df)
# Out:
# <Axes: xlabel='aanemia', ylabel='count'>

# %%
# 52 % people having aanemia
# 340 % people not have aanemia.

# %%
df.appetite
# Out:
# 0      good
# 1      good
# 2      poor
# 3      poor
# 4      good
#        ...
# 395    good
# 396    good
# 397    good
# 398    good
# 399    good
# Name: appetite, Length: 400, dtype: object

# %%
sns.countplot(x = 'appetite' , data=df)
# Out:
# <Axes: xlabel='appetite', ylabel='count'>

# %%
## pie chart

# %%
df['appetite'].value_counts().plot.pie(colors = ['yellow' , 'blue'] , autopct ='%1.0f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['appetite'].value_counts().plot.pie(colors = ['yellow' , 'blue'] , autopct ='%1.0f%%', explode=(0,0.1))
# Out:
# <Axes: ylabel='count'>

# %%
# insight :
# 79% people has good appetite
# 21% people has bad appetite.

# %%
df['appetite'].value_counts().plot.pie(colors = ['yellow' , 'blue'] , autopct ='%1.0f%%' , wedgeprops = dict(width=0.3))
# Out:
# <Axes: ylabel='count'>

# %%
# startangle = 90 , start other value from 90 degree angle

# is a pie chart.

df['appetite'].value_counts().plot.pie(colors = ['yellow' , 'blue'] , autopct ='%1.0f%%' , wedgeprops = dict(width=0.3) , startangle = 90)
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
# if we want to analyse -
#Q. how many ppl having cronic disease & hypertension with poor appetite?

# %%
plt.figure(figsize = (15 , 12))
plotnumber = 1

for col in num_cols:
  if plotnumber <= 15:
    ax = plt.subplot(3,5 , plotnumber)
    sns.distplot(df[col])
    plt.xlabel(col)
  plotnumber += 1

plt.tight_layout()
plt.show()

# %%
def kde(col):
  grid = sns.FacetGrid(df , hue = 'class' , height = 4, aspect =2)
  grid.map(sns.kdeplot , col)
  grid.add_legend()

# %%
kde('white_blood_cell_count')

# %%
kde('haemoglobin')

# %%
def violin(col):
    fig =  px.violin(df, y=col , x='class' , box = True , template = 'plotly_dark')
    return fig.show()

# %%
violin('haemoglobin')

# %%
## insights : outlier are present , 3.1 & 4.8 ,16.1 for class 0

violin('packed_cell_volume')

# %%
violin('specific_gravity')

# %%
## bivariate 
## scatter plot

sns.scatterplot(x= 'age' , y = 'blood_pressure', data = df , hue = 'class')
# Out:
# <Axes: xlabel='age', ylabel='blood_pressure'>

# %%
## blue dot people having cronic disease
## red dot not having cronic diseases.
## most of peiple having cronic disease

## most of people have blood presure more than 100.
## hight BP cuases cronic disease.

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
diabeter_hypertension = pd.crosstab(df['diabetes_mellitus'], df['hypertension'])
diabeter_hypertension
# Out:
# hypertension        no  yes
# diabetes_mellitus
#  yes                 0    1
# no                 220   41
# yes                 31  105

# %%
### insight 
### 105 people have hypertension & diabetes_mellitus both
### 220 people not have hypertension & diabetes_mellitus
### 41 people having hypertension but not diabetes_mellitus
### 31 people having diabetes_mellitus not hypertension

# %%
### this is stack bar chart
diabetes_hypertension = pd.crosstab(df['diabetes_mellitus'], df['hypertension'])
diabetes_hypertension.plot(kind = 'bar', stacked = True, color = ['#6DA7DE', '#FF9A8B'], figsize = (10, 6))

plt.xlabel("diabetes_mellitus and hypertension")
plt.ylabel("count")
plt.legend(title="hypertension")
plt.title("stacked diabetes_mellitus and hypertension")
plt.show()

# %%
## insight 
##  analyse diabetes & hypertension both 
### people having hypertension show by red
### people not having hypertension show by blue
### 220 people have not hypertension & dibetes
### 105 people have hypertension & diabetes_mellitus both
### 41 people having hypertension but not diabetes_mellitus
### 31 people having diabetes_mellitus not hypertension

# %%
## its simple scatter plot , templete is dark ,

def scatter(col1, col2):
    fig = px.scatter(df, x = col1, y=col2, color = "class", template = "plotly_dark")
    return fig.show()

# %%
scatter('haemoglobin', 'packed_cell_volume')

# %%
## 0 class means cronic disease , 1 cls no cronic disease
### blue points means cronic disease , yellow parts means non cronic disease.
### click on any point and analyse it

# %%
### multivariate analysis

# %%
selected_coulmns = ['age' , 'blood_pressure' , 'haemoglobin' , 'class']
sns.pairplot(df[selected_coulmns], hue = 'class' , palette = 'husl')

# %%
## green color means having cronic disease
## red color means having non-cronic disease
### here i analyse age , blood_pressure , haemoglobin
### 40 yr old people have cronic disease

# %%
df[selected_coulmns].corr()
# Out:
#                      age  blood_pressure  haemoglobin     class
# age             1.000000        0.159480    -0.192928 -0.227268
# blood_pressure  0.159480        1.000000    -0.306540 -0.294077
# haemoglobin    -0.192928       -0.306540     1.000000  0.768919
# class          -0.227268       -0.294077     0.768919  1.000000

# %%
### age increse BP increse ,means positive corelation
###

# %%
sns.heatmap(df[selected_coulmns].corr() , annot = True , cmap ='coolwarm' , linewidth = .5)
# Out:
# <Axes: >

# %%
import plotly.graph_objects as go

heatmap_data = df[selected_coulmns].corr()

fig = go.Figure(data=go.Heatmap(z=heatmap_data.values,
                                x=heatmap_data.columns,
                                y=heatmap_data.index,
                                colorscale ='viridis'))

fig.update_layout(title='interactive heatmap of correlation matrix')
fig.show()

# %%
### 3D

fig = px.scatter_3d(df,x='age' , y='blood_pressure' , z='serum_creatinine' , color = 'haemoglobin',
                    title = '3D scatter plot with color gradient')

fig.show()

# %%
### 3d plot is best plot ever
## click on points of 3d plot , its gives all parameters for perticular point(bp, serum , hb)
